# %%
# importing libraries
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.cluster import KMeans
import joblib
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read dataset in dataframe
df = pd.read_csv("Driving Data(KIA SOUL)_(150728-160714)_(10 Drivers_A-J).csv")

# %%
df = df[['Fuel_consumption','Absolute_throttle_position', 'Engine_speed', 'Current_Gear', 'Steering_wheel_angle',
         'Steering_wheel_speed','Acceleration_speed_-_Longitudinal','Calculated_LOAD_value', 'Engine_coolant_temperature',
        'Activation_of_Air_compressor','Vehicle_speed', 'Indication_of_brake_switch_ON/OFF','Class']]

# %%
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'Country'. 
df['Class']= label_encoder.fit_transform(df['Class'])

# %%
scaler = StandardScaler()

# Fit and transform the data
fit_data = scaler.fit(df)
normalized_data = fit_data.transform(df)
# Create a new DataFrame with the normalized data
df = pd.DataFrame(normalized_data, columns=df.columns)

# %%
joblib.dump(fit_data, 'fit_data.save')
# Out:
# ['fit_data.save']

# %%
df
# Out:
#        Fuel_consumption  Absolute_throttle_position  Engine_speed  \
# 0             -0.641211                   -0.501886     -0.805052
# 1             -0.674835                   -0.468771     -1.135981
# 2             -0.708458                   -0.468771     -1.202819
# 3             -0.725270                   -0.501886     -1.219121
# 4             -0.708458                   -0.468771     -1.152283
# ...                 ...                         ...           ...
# 94375         -0.540341                   -0.402540     -1.228902
# 94376         -0.540341                   -0.402540     -1.228902
# 94377         -0.540341                   -0.402540     -1.232162
# 94378         -0.557152                   -0.435656     -1.248464
# 94379         -0.624399                   -0.468771     -1.238683
#
#        Current_Gear  Steering_wheel_angle  Steering_wheel_speed  \
# 0         -1.511732             -0.068628             -0.240391
# ...

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                                    Fuel_consumption  \
# Fuel_consumption                           1.000000
# Absolute_throttle_position                 0.823044
# Engine_speed                               0.731023
# Current_Gear                               0.230235
# Steering_wheel_angle                      -0.000461
# Steering_wheel_speed                      -0.032212
# Acceleration_speed_-_Longitudinal          0.582281
# Calculated_LOAD_value                      0.779371
# Engine_coolant_temperature                 0.015219
# Activation_of_Air_compressor              -0.025755
# Vehicle_speed                              0.438677
# Indication_of_brake_switch_ON/OFF         -0.424470
# Class                                     -0.079265
#
#                                    Absolute_throttle_position  Engine_speed  \
# Fuel_consumption                                     0.823044      0.731023
# Absolute_throttle_position                           1.000000      0.550361
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, center=0, annot=True)
plt.show()

# %%
df
# Out:
#        Fuel_consumption  Absolute_throttle_position  Engine_speed  \
# 0                 268.8                        13.3           929
# 1                 243.2                        13.7           726
# 2                 217.6                        13.7           685
# 3                 204.8                        13.3           675
# 4                 217.6                        13.7           716
# ...                 ...                         ...           ...
# 94375             345.6                        14.5           669
# 94376             345.6                        14.5           669
# 94377             345.6                        14.5           667
# 94378             332.8                        14.1           657
# 94379             281.6                        13.7           663
#
#        Current_Gear  Steering_wheel_angle  Steering_wheel_speed  \
# 0                 0                  -3.4                     0
# ...

# %%
kmeans = KMeans(n_clusters=10, random_state=42)
kmeans_fit = kmeans.fit(df)
# Out:
# C:\Users\Rohit Dudhal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df
# Out:
#        Fuel_consumption  Absolute_throttle_position  Engine_speed  \
# 0                 268.8                        13.3           929
# 1                 243.2                        13.7           726
# 2                 217.6                        13.7           685
# 3                 204.8                        13.3           675
# 4                 217.6                        13.7           716
# ...                 ...                         ...           ...
# 94375             345.6                        14.5           669
# 94376             345.6                        14.5           669
# 94377             345.6                        14.5           667
# 94378             332.8                        14.1           657
# 94379             281.6                        13.7           663
#
#        Current_Gear  Steering_wheel_angle  Steering_wheel_speed  \
# 0                 0                  -3.4                     0
# ...

# %%
joblib.dump(kmeans, 'kmeans_model_13.joblib')
# Out:
# ['kmeans_model_13.joblib']
